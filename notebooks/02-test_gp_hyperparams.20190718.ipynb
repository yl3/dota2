# %% [markdown]
# # Try different hyperparameters of the TI9 dataset.

# %% [markdown]
# ## Setup

# %%
import os
import sys

os.chdir("..")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from src import load, munge
import src.models.gp

# %%
import importlib
importlib.reload(src.load)
importlib.reload(src.munge)
importlib.reload(src.models.gp)
# Out:
# <module 'src.models.gp' from '/Users/yl3/github/dota2/src/models/gp.py'>

# %% [markdown]
# ## Load data.

# %%
matches = load.all_matches_df()

# %%
matches_ti9 = matches.loc[matches.league_name == "The International 2019"]
matches_ti9.shape
# Out:
# (268, 15)

# %%
players_mat_ti9 = munge.make_match_players_matrix(
    matches_ti9.radiant_players, matches_ti9.dire_players)
players_mat_ti9.shape
# Out:
# (268, 240)

# %% [markdown]
# ## Run model: very large covariance function scale.

# %%
twenty_years_in_ms = 20 * 365 * 24 * 60 * 60 * 1000

# %%
gp = src.models.gp.SkillsGP(players_mat_ti9.values,
                            matches_ti9.startTimestamp,
                            matches_ti9.radiantVictory,
                            matches_ti9.columns.values,
                            "exponential", {"scale": twenty_years_in_ms / 10},
                            propose_sd=0.1, save_every_n_iter=10)

# %%
gp.iterate(10000)
# Out:
# 100% (10000 of 10000) |##################| Elapsed Time: 0:01:20 Time:  0:01:20

# %% [markdown]
# ### Explore the fitted data.

# %%
plt.plot([x[0] for x in gp.samples], [x[2] for x in gp.samples])

# %%
name_of_player_id = munge.player_id_to_player_name(
    pd.concat([matches_ti9.radiant_players, matches_ti9.dire_players]),
    pd.concat([matches_ti9.radiant_nicknames, matches_ti9.dire_nicknames]),
    pd.concat([matches_ti9.radiant_valveId, matches_ti9.dire_valveId]),
    pd.concat([matches_ti9.radiant_name, matches_ti9.dire_name]),)

# %%
name_of_player_id.loc[name_of_player_id.team.isin(["beastcoast"])]
# Out:
#                name        team     team_id
# 31818853       Brax  beastcoast  beastcoast
# 86715129   ixmike88  beastcoast  beastcoast
# 115141430     Ryoya  beastcoast  beastcoast
# 131706718     M-GOD  beastcoast  beastcoast
# 349310876      MoOz  beastcoast  beastcoast

# %%
skills_vecs = np.array([x[1] for x in gp.samples[-1000:]])

# %%
fitted_skills = pd.DataFrame(
    gp.to_mat(skills_vecs.mean(0)),
    columns=name_of_player_id.name[players_mat_ti9.columns],
    index=matches_ti9.startDate
)

# %%
fitted_sd = pd.DataFrame(
    gp.to_mat(skills_vecs.std(0)),
    columns=name_of_player_id.name[players_mat_ti9.columns],
    index=matches_ti9.startDate
)

# %%
beastcoast_players = \
    name_of_player_id.name[name_of_player_id.team == "beastcoast"]
plt.plot(fitted_skills.loc[:, beastcoast_players].dropna().sum(1))

# %%
(fitted_sd.loc[:, beastcoast_players].dropna() ** 2).sum(1) ** 0.5
# Out:
# startDate
# 2019-07-14 20:18:11    0.870360
# 2019-07-14 19:02:07    1.342075
# 2019-07-13 21:37:01    1.083105
# 2019-07-13 20:37:17    1.003351
# 2019-07-13 19:13:43    1.110301
# 2019-07-13 18:04:37    0.760853
# 2019-07-12 21:20:54    0.860079
# 2019-07-12 19:18:44    0.716367
# 2019-07-12 02:00:18    0.885200
# 2019-07-12 00:33:39    0.895704
# 2019-07-11 22:14:41    1.261970
# 2019-07-11 19:40:06    0.851157
# 2019-07-11 17:30:21    1.152352
# dtype: float64

# %% [markdown]
# ### How do the covariance matrices look like?

# %%
name_of_player_id.loc[name_of_player_id.name == "ixmike88"]
# Out:
#               name        team     team_id
# 86715129  ixmike88  beastcoast  beastcoast

# %%
gp.cov_mat[players_mat_ti9.columns == "86715129"]
# Out:
# array([[1.        , 0.99988999, 0.99980703, 0.99888537, 0.99869278,
#         0.99861855, 0.99843687],
#        [0.99988999, 1.        , 0.99991703, 0.99899527, 0.99880266,
#         0.99872842, 0.99854672],
#        [0.99980703, 0.99991703, 1.        , 0.99907816, 0.99888553,
#         0.99881129, 0.99862957],
#        [0.99888537, 0.99899527, 0.99907816, 1.        , 0.99980719,
#         0.99973288, 0.999551  ],
#        [0.99869278, 0.99880266, 0.99888553, 0.99980719, 1.        ,
#         0.99992568, 0.99974375],
#        [0.99861855, 0.99872842, 0.99881129, 0.99973288, 0.99992568,
#         1.        , 0.99981807],
#        [0.99843687, 0.99854672, 0.99862957, 0.999551  , 0.99974375,
#         0.99981807, 1.        ]])

# %% [markdown]
# ### What is the observed and expected outcome?

# %%
win_prob = src.models.gp.compute_match_win_prob(players_mat_ti9,
                                                gp.to_mat(gp.samples[-1][1]))

# %%
matches_ti9.loc[:, 'win_prob'] = win_prob
matches_ti9.loc[:, ['win_prob', 'radiantVictory']]
# Out:
#             win_prob  radiantVictory
# matchId
# 4904311356  0.728454           False
# 4904261164  0.416905            True
# 4904218149  0.543742           False
# 4904171017  0.192231           False
# 4904062522  0.395476           False
# 4903974414  0.529263           False
# 4903679968  0.296984            True
# 4903566049  0.306126           False
# 4903441151  0.548804            True
# 4903243468  0.458466            True
# 4903157391  0.510972           False
# 4903091581  0.508152           False
# 4903051772  0.665155            True
# 4902924459  0.425796           False
# 4902837041  0.463329           False
# 4902729928  0.481883            True
# 4902576905  0.510377            True
# 4902464697  0.352276            True
# 4902354217  0.668038            True
# 4902186317  0.280311           False
# 4902122478  0.725165           False
# 4902056634  0.243275           False
# 4901998619  0.248455           False
# 4901925673  0.277845           False
# 4901835876  0.361906            True
# 4901799568  0.518837            True
# 4901742097  0.420183            True
# 4901733286  0.333981           False
# 4901728834  0.422325            True
# 4901646019  0.409120           False
# ...              ...             ...
# 4890122311  0.563518            True
# 4889995626  0.347251           False
# 4889981518  0.480678            True
# 4889881001  0.680708            True
# 4889865830  0.618636            True
# 4889722230  0.667949            True
# 4889691529  0.674508           False
# 4889635707  0.574585            True
# 4889610539  0.633046           False
# 4889555136  0.289707            True
# 4889525518  0.544165           False
# 4889502467  0.364766            True
# 4889496502  0.678941           False
# 4889464422  0.270778            True
# 4889414157  0.596360            True
# 4889360849  0.441290            True
# 4889343439  0.330817           False
# 4889341660  0.351353           False
# 4889265404  0.498444           False
# 4889233900  0.395296           False
# 4889163811  0.465970           False
# 4889115579  0.786701           False
# 4889038294  0.511101            True
# 4888974952  0.867566            True
# 4888936676  0.619254            True
# 4888859291  0.589951           False
# 4888772755  0.559376           False
# 4888732113  0.601465           False
# 4888686136  0.290115           False
# 4888646940  0.511700            True
#
# [268 rows x 2 columns]

# %%
plt.scatter(matches_ti9.win_prob,
            matches_ti9.radiantVictory + np.random.uniform(size=matches_ti9.shape[0]) / 5 - .1)

# %% [markdown]
# ## Test the basic win probability functionality.

# %%
src.models.gp.win_prob(2)  # Should be around 60%
# Out:
# 0.598687660112452

# %%
src.models.gp.win_prob(0)  # Should be 50%
# Out:
# 0.5

# %%
src.models.gp.win_prob(10) # 85-90%
# Out:
# 0.8807970779778823

# %% [markdown]
# ## Do the likelihoods come from prior or posterior?
#
# Answer: they come from the priors...

# %%
[(x[3], x[4]) for x in gp.samples[-100:]]
# Out:
# [(-8666007.033048784, -209.1112987825406),
#  (-8773632.863779567, -208.24574979390542),
#  (-8632879.037117707, -207.7412353093519),
#  (-8596573.087223882, -207.12395891807654),
#  (-8652270.977072477, -207.8994752410528),
#  (-8660650.221291479, -208.59300403989093),
#  (-8711442.284397105, -207.31027581086224),
#  (-8614654.899382135, -207.95364282345093),
#  (-8642105.351620544, -207.21304608780852),
#  (-8715159.786720267, -206.2818343103167),
#  (-8600567.954793764, -207.52519468328344),
#  (-8641622.397585122, -208.35400170202405),
#  (-8589552.08277977, -208.2255006327827),
#  (-8617344.783700045, -209.35591858305523),
#  (-8685341.563909117, -208.12254425495846),
#  (-8622978.625963442, -207.87135997337055),
#  (-8621614.950165551, -207.3892357568691),
#  (-8560642.404977897, -207.34331592477832),
#  (-8680050.494517116, -207.0099056177287),
#  (-8447806.862071835, -206.76854271841742),
#  (-8598137.476525733, -207.51805013600216),
#  (-8533207.391164461, -206.78198522198855),
#  (-8519337.62231253, -206.42845111320938),
#  (-8582913.74142763, -206.533427020187),
#  (-8547150.713677615, -206.21338384227425),
#  (-8500069.791208794, -205.85244239709647),
#  (-8552425.469168602, -207.02822432433518),
#  (-8510809.816550404, -207.560367326926),
#  (-8497176.40512231, -207.73056166293136),
#  (-8471496.099911679, -207.2861339216837),
#  (-8519931.979671737, -205.52609221434994),
#  (-8540639.319272297, -207.32588072097786),
#  (-8532033.56759049, -208.03502187132213),
#  (-8583187.942928277, -206.46968671226975),
#  (-8520658.790968128, -206.74342997220836),
#  (-8594332.012265434, -206.808517242161),
#  (-8593804.015485723, -206.78324799177648),
#  (-8570227.61657591, -206.17804075073155),
#  (-8499181.549206603, -207.43197416486484),
#  (-8565242.98492978, -206.45342540521895),
#  (-8556044.545895746, -206.46826202306073),
#  (-8554618.34608863, -206.5810884849807),
#  (-8525924.51524013, -207.52401181433945),
#  (-8509123.078737915, -207.97720670244018),
#  (-8527626.712239513, -206.93101970992305),
#  (-8484988.398131557, -207.39252217859513),
#  (-8527859.847723903, -208.19889683976294),
#  (-8538037.733226871, -207.87864923016997),
#  (-8522043.11590076, -207.24659270699345),
#  (-8542915.824121628, -207.5746911508901),
#  (-8483264.64146281, -208.19227005900797),
#  (-8586284.354625732, -207.5324659951569),
#  (-8562409.407273246, -206.9903783383745),
#  (-8570503.027821189, -207.40064042447077),
#  (-8539797.36073737, -208.09427507343034),
#  (-8444806.14635712, -207.8017674292339),
#  (-8549590.579886543, -207.0604375059189),
#  (-8492654.598994529, -207.73558305361627),
#  (-8535435.10847997, -208.3883905138832),
#  (-8552539.758695882, -208.05310343669152),
#  (-8515648.224483479, -207.6949380890215),
#  (-8479486.72202434, -207.02477942137773),
#  (-8522778.404214382, -208.14006121312406),
#  (-8530201.747437768, -206.99418280325258),
#  (-8497324.92857296, -207.4232565571432),
#  (-8507468.600258622, -206.8632218265184),
#  (-8479337.848821197, -207.04088526172484),
#  (-8398916.847269038, -207.44699556663554),
#  (-8413520.53553776, -207.72576176370382),
#  (-8511972.607660897, -207.03943555047658),
#  (-8485356.414353501, -207.05460901167987),
#  (-8483953.57691527, -206.1012218098807),
#  (-8399322.942146413, -207.0941930869948),
#  (-8493287.677137332, -206.88687289690228),
#  (-8528750.125758376, -206.06761391950067),
#  (-8493987.418707637, -206.4477096803785),
#  (-8489652.624241222, -207.06473040957607),
#  (-8406410.606249558, -206.42247545830304),
#  (-8504057.278868364, -207.16455502611706),
#  (-8516062.338006873, -208.03128983226716),
#  (-8434355.377869407, -207.28229535499617),
#  (-8432076.75938429, -208.23935630883943),
#  (-8504583.480344651, -207.30607579246478),
#  (-8399822.951528935, -207.32722455458344),
#  (-8388648.531462705, -207.80603608307638),
#  (-8440162.911116092, -207.12241278879813),
#  (-8467131.890656943, -207.6865442325573),
#  (-8428118.323730273, -207.30924343016872),
#  (-8581050.859295381, -207.49513912438164),
#  (-8536482.771870982, -206.72588332818395),
#  (-8455057.219829042, -208.04979901064647),
#  (-8364577.726288605, -206.6161133206203),
#  (-8543062.906063851, -207.17564284808708),
#  (-8511667.989406036, -206.9297778796793),
#  (-8435356.169736076, -206.6425806937019),
#  (-8470762.385561744, -207.37659781024905),
#  (-8544365.774633553, -206.43259468782912),
#  (-8427202.120525869, -206.14806135681988),
#  (-8436934.538210893, -207.29570499691317),
#  (-8450812.866578804, -206.59102545987614)]

# %% [markdown]
# ## Can we initialise using BFBS?

# %%
import scipy.optimize

# %%
scipy.optimize.minimize(lambda x: -gp.compute_log_posterior(x),
                        np.repeat(0.0, gp.M * 10),
                        method = "BFGS")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-e5e2291b93f3> in <module>
#       1 scipy.optimize.minimize(lambda x: -gp.compute_log_posterior(x),
#       2                         np.repeat(0.0, gp.M * 10),
# ----> 3                         method = "BFGS")
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     592         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     593     elif meth == 'bfgs':
# --> 594         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     595     elif meth == 'newton-cg':
#     596         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1014             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
#    1015                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# -> 1016                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1017         except _LineSearchError:
#    1018             # Line search failed to find a better solution.
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     834     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     835                              old_fval, old_old_fval,
# --> 836                              **kwargs)
#     837
#     838     if ret[0] is not None and extra_condition is not None:
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     174             alpha1 = stp
#     175             phi1 = phi(stp)
# --> 176             derphi1 = derphi(stp)
#     177         else:
#     178             break
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/linesearch.py in derphi(s)
#      88
#      89     def derphi(s):
# ---> 90         gval[0] = fprime(xk + s*pk, *newargs)
#      91         if gradient:
#      92             gc[0] += 1
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in approx_fprime(xk, f, epsilon, *args)
#     754
#     755     """
# --> 756     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     757
#     758
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# ~/anaconda3/envs/dota2-3.7.2/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# <ipython-input-80-e5e2291b93f3> in <lambda>(x)
# ----> 1 scipy.optimize.minimize(lambda x: -gp.compute_log_posterior(x),
#       2                         np.repeat(0.0, gp.M * 10),
#       3                         method = "BFGS")
#
# ~/github/dota2/src/models/gp.py in compute_log_posterior(self, skills_vec)
#     207         assert len(skills_vec) == self.M * 10
#     208         skills_mat = self.to_mat(skills_vec)
# --> 209         prior_logprob = sum(
#     210             self._skills_mat_prior_logprob(skills_mat))
#     211         loglik = np.sum(self._match_loglik(skills_mat))
#
# ~/github/dota2/src/models/gp.py in _skills_mat_prior_logprob(self, skills_mat)
#     191         for i in range(self.N):
#     192             skills_vec = skills_mat[:, i]
# --> 193             skills_vec_f = skills_vec[~np.isnan(skills_vec)]
#     194             logprob = self.prior_multinorm[i].logpdf(skills_vec_f)
#     195             player_prior_logprobs.append(logprob)
#
# KeyboardInterrupt:
