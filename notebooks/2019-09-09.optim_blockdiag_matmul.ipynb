# %% [markdown]
# # Optimise block diagonal matrix multiplication
#
# Optimise computing an operation of multiplying a block diagonal matrix with a vector, which is the bottleneck in the current `SkillsGPMAP.fit()` step.

# %% [markdown]
# ## Setup.

# %%
import os
if 'src' not in os.listdir():
    os.chdir("..")

# %%
import gzip
import importlib
import json
import pickle

import numpy as np
import pandas as pd
import scipy.linalg

import numba

from src import load
import src.models.gp
import src.stats
import src.statics

# %%
pd.set_option('max_rows', 6)
pd.set_option('max_columns', 50)

# %% [markdown]
# ## Load data.

# %%
with gzip.open('data/raw/premium_matches.2019-08-31.json.gz', 'rb') as fh:
    premium_matches = load.matches_json_to_df(json.load(fh)['data'])
    prm_m = load.MatchDF(premium_matches)

# %%
premium_pro_model = src.models.gp.SkillsGPMAP(
    None,
    None,
    prm_m.players_mat,
    prm_m.df.startTimestamp,
    prm_m.df.radiantVictory,
    'exponential',
    {'scale': 1.25 * 365 * 24 * 60 * 60 * 1000},
    radi_prior_sd=3.0,
    logistic_scale=3.0)

# %%
minus_inv_cov_mats = [np.ascontiguousarray(-scipy.linalg.inv(x))
                      for x in premium_pro_model.cov_mats]
radi_adv_cov_mat = np.full((1, 1),
                           -1 / (premium_pro_model.radi_prior_sd ** 2))
minus_inv_cov_mat_list = minus_inv_cov_mats + [radi_adv_cov_mat]

# %%
minus_inv_cov_mat_list[0].flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
radi_adv_cov_mat.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
size = sum([x.shape[0] for x in minus_inv_cov_mat_list])
size
# Out:
# 50001

# %%
p = np.repeat(0.0, size)
p
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ## Timings

# %% [markdown]
# ### Current implementation using `scipy.sparse.block_diag()`.

# %%
minus_inv_cov_mat = scipy.sparse.block_diag(minus_inv_cov_mat_list,
                                            format='csr')

# %%
# %timeit minus_inv_cov_mat @ p
# Out:
# 9.92 ms ± 453 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### By manually splitting and concatenating *p*

# %%
breaks = np.cumsum([x.shape[0] for x in minus_inv_cov_mat_list])
breaks
# Out:
# array([  110,   150,   298,   349,   410,   423,   628,   655,   959,
#         1108,  1184,  1405,  1415,  1581,  1584,  1829,  1850,  1851,
#         1883,  1904,  1928,  1975,  1977,  1983,  2254,  2364,  2415,
#         2670,  2723,  2867,  2873,  3013,  3034,  3045,  3335,  3336,
#         3341,  3414,  3421,  3425,  3458,  3462,  3566,  3706,  3713,
#         4010,  4014,  4018,  4267,  4279,  4384,  4387,  4566,  4571,
#         4621,  4842,  4848,  4869,  4899,  4905,  4907,  5159,  5162,
#         5202,  5203,  5210,  5265,  5323,  5342,  5373,  5376,  5499,
#         5527,  5535,  5586,  5587,  5589,  5590,  5613,  5678,  5687,
#         5718,  5800,  5824,  5832,  5846,  6094,  6095,  6105,  6106,
#         6426,  6427,  6446,  6448,  6482,  6518,  6770,  6776,  6779,
#         6782,  6790,  6802,  6998,  7271,  7366,  7534,  7535,  7577,
#         7579,  7584,  7591,  7774,  7781,  8012,  8189,  8214,  8269,
#         8291,  8297,  8304,  8316,  8320,  8440,  8453,  8778,  8995,
#         9139,  9162,  9383,  9667, 10008, 10259, 10263, 10534, 10536,
#        10541, 10567, 10581, 10613, 10614, 10839, 10855, 11172, 11188,
#        11256, 11267, 11349, 11356, 11358, 11424, 11425, 11432, 11438,
#        11459, 11559, 11563, 11593, 11599, 11860, 12024, 12161, 12281,
#        12316, 12496, 12792, 12910, 12916, 12952, 13121, 13129, 13136,
#        13144, 13271, 13280, 13331, 13586, 13588, 13684, 13713, 13740,
#        13759, 13918, 14214, 14236, 14258, 14261, 14417, 14421, 14611,
#        14616, 14673, 14718, 14719, 14859, 14871, 14982, 15008, 15029,
#        15033, 15090, 15159, 15166, 15281, 15395, 15550, 15556, 15826,
#        15963, 15994, 16026, 16031, 16065, 16074, 16101, 16108, 16120,
#        16122, 16166, 16217, 16505, 16525, 16526, 16530, 16575, 16685,
#        16695, 16716, 16721, 16817, 16962, 17046, 17048, 17229, 17272,
#        17521, 17732, 17755, 18052, 18103, 18394, 18454, 18506, 18509,
#        18510, 18801, 18817, 18922, 18987, 18999, 19157, 19212, 19213,
#        19219, 19332, 19365, 19501, 19504, 19507, 19535, 19536, 19548,
#        19865, 19894, 20020, 20090, 20143, 20266, 20273, 20327, 20363,
#        20379, 20383, 20418, 20547, 20561, 20564, 20663, 20665, 20817,
#        20831, 20836, 21002, 21004, 21235, 21251, 21258, 21316, 21339,
#        21404, 21417, 21534, 21538, 21557, 21574, 21590, 21604, 21608,
#        21628, 21635, 21644, 21725, 21998, 22038, 22198, 22214, 22228,
#        22254, 22260, 22551, 22605, 22607, 22847, 22859, 22860, 22861,
#        22863, 22881, 22901, 22902, 22940, 22944, 22945, 22954, 22958,
#        23230, 23232, 23242, 23249, 23325, 23329, 23330, 23370, 23392,
#        23399, 23400, 23423, 23424, 23431, 23452, 23461, 23464, 23549,
#        23573, 23835, 23837, 23858, 23859, 23862, 23864, 24165, 24169,
#        24273, 24541, 24557, 24615, 24621, 24633, 24634, 24637, 24644,
#        24645, 24956, 24966, 24971, 24990, 24993, 25004, 25203, 25475,
#        25494, 25514, 25516, 25523, 25529, 25532, 25698, 25711, 25720,
#        25727, 25734, 25742, 25843, 25922, 25945, 25946, 25993, 26141,
#        26322, 26529, 26540, 26627, 26666, 26675, 26913, 26925, 26927,
#        26968, 27113, 27120, 27123, 27130, 27144, 27148, 27150, 27159,
#        27169, 27256, 27295, 27416, 27687, 27688, 27698, 27895, 27950,
#        28089, 28216, 28222, 28224, 28225, 28437, 28471, 28509, 28513,
#        28678, 28696, 28699, 28711, 28713, 28723, 28743, 28748, 28759,
#        28862, 29158, 29160, 29225, 29238, 29329, 29354, 29417, 29420,
#        29428, 29583, 29587, 29762, 29886, 29961, 29963, 30166, 30215,
#        30281, 30294, 30442, 30554, 30578, 30581, 30588, 30598, 30629,
#        30641, 30642, 30693, 30694, 30922, 30936, 30997, 30999, 31000,
#        31012, 31017, 31021, 31023, 31033, 31045, 31046, 31127, 31231,
#        31233, 31498, 31499, 31517, 31536, 31538, 31547, 31554, 31584,
#        31586, 31591, 31634, 31676, 31693, 31705, 31781, 31791, 31809,
#        31838, 31868, 31955, 31957, 32156, 32161, 32187, 32249, 32256,
#        32280, 32321, 32332, 32350, 32361, 32369, 32371, 32373, 32561,
#        32570, 32625, 32781, 32792, 32799, 32818, 32821, 32884, 32885,
#        32891, 32903, 32914, 33089, 33125, 33426, 33434, 33435, 33450,
#        33451, 33455, 33701, 34002, 34010, 34011, 34062, 34063, 34122,
#        34126, 34139, 34142, 34333, 34335, 34368, 34372, 34373, 34381,
#        34383, 34416, 34422, 34515, 34516, 34567, 34569, 34625, 34936,
#        35012, 35018, 35019, 35030, 35046, 35079, 35155, 35156, 35157,
#        35248, 35273, 35293, 35294, 35421, 35424, 35593, 35847, 36143,
#        36164, 36246, 36253, 36267, 36270, 36280, 36281, 36296, 36297,
#        36425, 36427, 36469, 36713, 36720, 36819, 36842, 36890, 36895,
#        36897, 36899, 36909, 37137, 37150, 37151, 37337, 37338, 37344,
#        37345, 37449, 37453, 37474, 37475, 37476, 37527, 37529, 37570,
#        37755, 37756, 37886, 37948, 38166, 38173, 38276, 38287, 38288,
#        38528, 38535, 38661, 38948, 38962, 38966, 39096, 39106, 39230,
#        39248, 39415, 39417, 39575, 39764, 40065, 40066, 40074, 40075,
#        40079, 40087, 40088, 40093, 40094, 40160, 40196, 40483, 40576,
#        40600, 40615, 40635, 40659, 40667, 40747, 40754, 40778, 40788,
#        40796, 40802, 40957, 40966, 41128, 41138, 41139, 41145, 41148,
#        41152, 41153, 41171, 41173, 41175, 41359, 41498, 41628, 41639,
#        41646, 41661, 41716, 41725, 41731, 41834, 41835, 41837, 41881,
#        41916, 41926, 41928, 41941, 41982, 41983, 42187, 42478, 42583,
#        42624, 42654, 42712, 42718, 42725, 42726, 42777, 42781, 42782,
#        42813, 42817, 42827, 42830, 42943, 42947, 43228, 43241, 43383,
#        43390, 43398, 43399, 43665, 43739, 43740, 43742, 43743, 43846,
#        43884, 43904, 43906, 44049, 44157, 44159, 44175, 44176, 44180,
#        44182, 44195, 44199, 44203, 44204, 44206, 44210, 44216, 44218,
#        44338, 44345, 44352, 44391, 44393, 44394, 44423, 44424, 44434,
#        44452, 44463, 44466, 44525, 44540, 44569, 44577, 44593, 44611,
#        44612, 44622, 44654, 44705, 44721, 44723, 44731, 44767, 44815,
#        44817, 44893, 44897, 44903, 44904, 44906, 44935, 44944, 44946,
#        44952, 45140, 45165, 45189, 45197, 45205, 45223, 45227, 45256,
#        45257, 45258, 45271, 45272, 45273, 45274, 45275, 45574, 45578,
#        45579, 45587, 45592, 45673, 45683, 45685, 45688, 45737, 45942,
#        45944, 46034, 46058, 46119, 46249, 46251, 46271, 46272, 46282,
#        46284, 46454, 46458, 46465, 46546, 46609, 46620, 46621, 46633,
#        46689, 46747, 46748, 46765, 46900, 46909, 46917, 46918, 46936,
#        46943, 46951, 47167, 47182, 47183, 47186, 47260, 47264, 47271,
#        47279, 47281, 47298, 47306, 47312, 47313, 47449, 47665, 47680,
#        47688, 47713, 47716, 47722, 47723, 47834, 47845, 47858, 47860,
#        47861, 47868, 47870, 47871, 48008, 48018, 48030, 48049, 48050,
#        48060, 48061, 48064, 48077, 48120, 48123, 48138, 48139, 48148,
#        48151, 48172, 48175, 48217, 48219, 48229, 48264, 48267, 48280,
#        48287, 48416, 48426, 48427, 48434, 48457, 48465, 48474, 48498,
#        48500, 48506, 48508, 48518, 48519, 48524, 48525, 48526, 48527,
#        48529, 48548, 48662, 48663, 48667, 48771, 48774, 48904, 48906,
#        48907, 48909, 48920, 48923, 48924, 48925, 49146, 49183, 49425,
#        49533, 49534, 49625, 49690, 49694, 49698, 49709, 49716, 49718,
#        49873, 49883, 49895, 49896, 49915, 49925, 49927, 49929, 49936,
#        49951, 49955, 49958, 49960, 49964, 49974, 49977, 49987, 49994,
#        49995, 49998, 50000, 50001])

# %%
def block_diag_list_mult(mat_list, split_p):
    out_vals = []
    for mm, pp in zip(mat_list, split_p):
        out_vals.append(mm @ pp)
    return np.concatenate(out_vals)

# %%
split_p = np.split(p, breaks[:-1])
# %timeit block_diag_list_mult(minus_inv_cov_mat_list, split_p)
# Out:
# 11 ms ± 3.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### By using numba

# %%
@numba.jit(nopython=True)
def block_diag_list_mult_jit(mat_list, p, breaks):
    out_vec = np.zeros(p.size)
    prev_i = 0
    for i in range(len(mat_list)):
        m = mat_list[i]
        b = breaks[i]
        out_vec[prev_i:b] = m @ p[prev_i:b]
        prev_i = b
    return out_vec

# %%
sum([x.shape[0] for x in minus_inv_cov_mat_list[:700]])
# Out:
# 42777

# %%
# %timeit block_diag_list_mult_jit(tuple(minus_inv_cov_mat_list), p, breaks)
# Out:
# 15.5 ms ± 2.04 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### By using numba with fastmath=True

# %%
@numba.jit(nopython=True, fastmath=True)
def block_diag_list_mult_jit(mat_list, p, breaks):
    out_vec = np.zeros(p.size)
    prev_i = 0
    for i in range(len(mat_list)):
        m = mat_list[i]
        b = breaks[i]
        out_vec[prev_i:b] = m @ p[prev_i:b]
        prev_i = b
    return out_vec

# %%
# %timeit block_diag_list_mult_jit(tuple(minus_inv_cov_mat_list), p, breaks)
# Out:
# 6.64 ms ± 444 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Try `SkillsGPMAP.fit()` with numba.

# %%
importlib.reload(src.models.gp)
premium_pro_model = src.models.gp.SkillsGPMAP(
    None,
    None,
    prm_m.players_mat,
    prm_m.df.startTimestamp,
    prm_m.df.radiantVictory,
    'exponential',
    {'scale': 1.25 * 365 * 24 * 60 * 60 * 1000},
    radi_prior_sd=3.0,
    logistic_scale=3.0)

# %%
premium_pro_model.fit()
