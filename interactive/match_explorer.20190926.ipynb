# %% [markdown]
# # A widget for interactive analysis of a matchup

# %% [markdown]
# ## Input parameters.

# %%
TEAM_1 = 'beastcoast'
TEAM_2 = 'j.storm'

FORCE_REFIT = False

LOGISTIC_SCALE = 3.0
COV_FUNC_NAME = 'exponential'
COV_FUNC_KWARGS = {'scale': 1.25 * 365 * 24 * 60 * 60 * 1000}
RADI_PRIOR_SD = 3.0

# %%
TEAM_1 = TEAM_1.lower()
TEAM_2 = TEAM_2.lower()

# %% [markdown]
# ## Load libraries.

# %%
import os
while 'src' not in os.listdir():
    os.chdir('..')
os.getcwd()
# Out:
# '/Users/yl3/github/dota2'

# %%
import dill
import pandas as pd

import src.load
import src.models.gp
import src.stats

# %% [markdown]
# ## Load data.

# %%
def load_premium_prof_matches():
    prem_matches = src.load.fetch_matches()
    prof_matches = src.load.fetch_matches('professional')
    matches = src.load.MatchDF(pd.concat([prem_matches.df, prof_matches.df]))
    return prem_matches

# %%
def _match_date(matches):
    """Compute the match dates of each team by team name.

    Args:
        matches (load.MatchDF): The match data.
    """
    radi_teams = matches.df[['radiant_name', 'radiant_valveId',
                             'radiant_nicknames', 'radiant_players',
                             'startDate']]
    dire_teams = matches.df[['dire_name', 'dire_valveId',
                             'dire_nicknames', 'dire_players',
                             'startDate']]
    colnames = ['team_name', 'team_id', 'player_names', 'player_ids',
                'startDate']
    radi_teams.columns = colnames
    dire_teams.columns = colnames
    teams_by_date = (pd.concat([radi_teams, dire_teams])
                     .sort_values('startDate')
                     .reset_index())
    for colname in ('matchId', 'team_id'):
        teams_by_date[colname] = \
            teams_by_date[colname].astype(pd.Int64Dtype())
    teams_by_date['team_name'] = teams_by_date['team_name'].str.lower()
    teams_by_date.index = teams_by_date['team_name']
    return teams_by_date

# %%
serialised_model_file = 'interactive/latest_fitted_gp_model.dill'
if FORCE_REFIT or not os.path.isfile(serialised_model_file):
    matches = load_premium_prof_matches()
    gp_model = src.models.gp.SkillsGPMAP.from_match_df(
        matches,
        cov_func_name=COV_FUNC_NAME,
        cov_func_kwargs=COV_FUNC_KWARGS,
        radi_prior_sd=RADI_PRIOR_SD,
        logistic_scale=LOGISTIC_SCALE
    )
    gp_model.fit()
    display(gp_model.fitted)
    match_pred = src.stats.MatchPred(
    matches,
    gp_model.fitted_pred_df(),
    gp_model.logistic_scale,
    gp_model.fitted_skills_mat())
    with open(serialised_model_file, 'wb') as fh:
        dill.dump(match_pred, fh)
else:
    with open(serialised_model_file, 'rb') as fh:
        match_pred = dill.load(fh)

# %% [markdown]
# ### Compute team selectors.

# %%
loc1 = ((match_pred.df.radiant_name.str.lower() == TEAM_1)
        | (match_pred.df.dire_name.str.lower() == TEAM_1))
loc2 = ((match_pred.df.radiant_name.str.lower() == TEAM_2)
        | (match_pred.df.dire_name.str.lower() == TEAM_2))
if sum(loc1):
    team1_id = \
        match_pred.teams.index[match_pred.teams.str.lower() == TEAM_1][-1]
if sum(loc2):
    team2_id = \
        match_pred.teams.index[match_pred.teams.str.lower() == TEAM_2][-1]

# Get the most recent roster of both teams.
match_dates = _match_date(match_pred)
team_1_players = match_dates.loc[
    match_dates.team_id == team1_id, 'player_ids'].iloc[-1]
team_2_players = match_dates.loc[
    match_dates.team_id == team2_id, 'player_ids'].iloc[-1]
    
display(match_pred.teams[match_pred.teams.str.lower() == TEAM_1])
display(match_pred.teams[match_pred.teams.str.lower() == TEAM_2])
print(f"{sum(loc1)} matches for team 1.")
print(f"{sum(loc2)} matches for team 2.")
# Out:
# 7079109    beastcoast
# dtype: object
# 6288801    J.Storm
# 7409177    J.Storm
# dtype: object
# 55 matches for team 1.
# 191 matches for team 2.

# %% [markdown]
# ## Actual interactive plots

# %% [markdown]
# ### Previous matches of both teams.

# %%
match_pred.df.loc[loc1].tail(20)
# Out:
#                      startDate                            league_name  \
# matchId
# 4901742097 2019-07-13 18:04:37                 The International 2019
# 4901835876 2019-07-13 19:13:43                 The International 2019
# 4901925673 2019-07-13 20:37:17                 The International 2019
# 4901998619 2019-07-13 21:37:01                 The International 2019
# 4903974414 2019-07-14 19:02:07                 The International 2019
# 4904062522 2019-07-14 20:18:11                 The International 2019
# 4925450824 2019-07-25 19:00:01                         DOTA Summit 10
# 4925548100 2019-07-25 20:20:13                         DOTA Summit 10
# 4925641710 2019-07-25 21:56:00                         DOTA Summit 10
# 4925701385 2019-07-25 23:06:55                         DOTA Summit 10
# 4927303287 2019-07-26 16:03:38                         DOTA Summit 10
# 4927405757 2019-07-26 16:54:24                         DOTA Summit 10
# 4927726799 2019-07-26 20:46:06                         DOTA Summit 10
# 4927831428 2019-07-26 22:28:04                         DOTA Summit 10
# 4927909239 2019-07-27 00:21:47                         DOTA Summit 10
# 4927978545 2019-07-27 01:26:58                         DOTA Summit 10
# 4930013418 2019-07-27 19:29:27                         DOTA Summit 10
# 4930094248 2019-07-27 20:31:32                         DOTA Summit 10
# 4930173430 2019-07-27 21:46:58                         DOTA Summit 10
# 5032441973 2019-09-20 22:18:01  ESL One Hamburg 2019 powered by Intel
#
#                  radiant_name          dire_name  radiantVictory  \
# matchId
# 4901742097         beastcoast            J.Storm            True
# 4901835876         beastcoast            J.Storm            True
# 4901925673         beastcoast             Newbee           False
# 4901998619         beastcoast             Newbee           False
# 4903974414         beastcoast            J.Storm           False
# 4904062522         beastcoast            J.Storm           False
# 4925450824         beastcoast            J.Storm           False
# 4925548100            J.Storm         beastcoast           False
# 4925641710  compLexity Gaming         beastcoast           False
# 4925701385  compLexity Gaming         beastcoast            True
# 4927303287           Alliance         beastcoast            True
# 4927405757           Alliance         beastcoast            True
# 4927726799        paiN Gaming         beastcoast           False
# 4927831428        paiN Gaming         beastcoast            True
# 4927909239      Team Serenity         beastcoast           False
# 4927978545      Team Serenity         beastcoast           False
# 4930013418  compLexity Gaming         beastcoast            True
# 4930094248         beastcoast  compLexity Gaming            True
# 4930173430  compLexity Gaming         beastcoast            True
# 5032441973     Kids Next Door         beastcoast           False
#
#                                        radiant_nicknames  \
# matchId
# 4901742097          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4901835876          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4901925673          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4901998619          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4903974414          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4904062522          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4925450824          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4925548100           (Moo, Resolut1on, Fear, 1437, nine)
# 4925641710           (Limmp, Zfreek, Meracle, 343, tavo)
# 4925701385           (Limmp, Zfreek, Meracle, 343, tavo)
# 4927303287         (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4927405757         (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4927726799  (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4927831428  (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4927909239               (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4927978545               (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4930013418           (Limmp, Zfreek, Meracle, 343, tavo)
# 4930094248          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4930173430           (Limmp, Zfreek, Meracle, 343, tavo)
# 5032441973  (Scourge McDuck, Unknown, Kefka, ミフネ, Stars)
#
#                                               dire_nicknames  seriesId  \
# matchId
# 4901742097               (Moo, Resolut1on, Fear, 1437, nine)    347697
# 4901835876               (Moo, Resolut1on, Fear, 1437, nine)    347697
# 4901925673           (pieliedie, Sneyking, MSS, YawaR, CCnC)    347748
# 4901998619           (pieliedie, Sneyking, MSS, YawaR, CCnC)    347748
# 4903974414               (Moo, Resolut1on, Fear, 1437, nine)    348080
# 4904062522               (Moo, Resolut1on, Fear, 1437, nine)    348080
# 4925450824               (Moo, Resolut1on, Fear, 1437, nine)    351576
# 4925548100              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351576
# 4925641710              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351615
# 4925701385              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351615
# 4927303287              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351876
# 4927405757              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351876
# 4927726799              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351996
# 4927831428              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351996
# 4927909239              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    352035
# 4927978545              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    352035
# 4930013418              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    352409
# 4930094248               (Limmp, Zfreek, Meracle, 343, tavo)    352409
# 4930173430              (Brax, ixmike88, Ryoya, M-GOD, MoOz)    352409
# 5032441973  (Brax, ixmike88, monkeys-forever, Timado, Jubei)    369211
#
#             duration  radiant_valveId  ...  \
# matchId                                ...
# 4901742097      2490          7079109  ...
# 4901835876      2229          7079109  ...
# 4901925673      1847          7079109  ...
# 4901998619      1386          7079109  ...
# 4903974414      2495          7079109  ...
# 4904062522      1817          7079109  ...
# 4925450824      2952          7079109  ...
# 4925548100      2793          6288801  ...
# 4925641710      2476                3  ...
# 4925701385      2498                3  ...
# 4927303287      1372           111474  ...
# 4927405757      2195           111474  ...
# 4927726799      3650               67  ...
# 4927831428      3146               67  ...
# 4927909239      2098          5066616  ...
# 4927978545      2624          5066616  ...
# 4930013418      1948                3  ...
# 4930094248      2863          7079109  ...
# 4930173430      2559                3  ...
# 5032441973      2310          7253132  ...
#
#                                                  dire_players  league_id  \
# matchId
# 4901742097  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4901835876  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4901925673  (6922000, 10366616, 86726887, 108452107, 22166...      10749
# 4901998619  (6922000, 10366616, 86726887, 108452107, 22166...      10749
# 4903974414  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4904062522  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4925450824  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925548100  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4925641710  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4925701385  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927303287  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927405757  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927726799  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927831428  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927909239  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4927978545  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4930013418  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4930094248  (12231202, 50828662, 91369376, 111034589, 1179...      11162
# 4930173430  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 5032441973  (31818853, 86715129, 86811043, 97658618, 10427...      11275
#
#            startTimestamp  series_start_time  match_i_in_series  \
# matchId
# 4901742097  1563041077000      1563041077000                  0
# 4901835876  1563045223000      1563041077000                  1
# 4901925673  1563050237000      1563050237000                  0
# 4901998619  1563053821000      1563050237000                  1
# 4903974414  1563130927000      1563130927000                  0
# 4904062522  1563135491000      1563130927000                  1
# 4925450824  1564081201000      1564081201000                  0
# 4925548100  1564086013000      1564081201000                  1
# 4925641710  1564091760000      1564091760000                  0
# 4925701385  1564096015000      1564091760000                  1
# 4927303287  1564157018000      1564157018000                  0
# 4927405757  1564160064000      1564157018000                  1
# 4927726799  1564173966000      1564173966000                  0
# 4927831428  1564180084000      1564173966000                  1
# 4927909239  1564186907000      1564186907000                  0
# 4927978545  1564190818000      1564186907000                  1
# 4930013418  1564255767000      1564255767000                  0
# 4930094248  1564259492000      1564255767000                  1
# 4930173430  1564264018000      1564255767000                  2
# 5032441973  1569017881000      1569017881000                  0
#
#             pred_win_prob  radi_skill  dire_skill  pred_win_prob_unknown_side  \
# matchId
# 4901742097       0.505886    0.632571    0.889867                    0.478636
# 4901835876       0.505910    0.632373    0.889377                    0.478660
# 4901925673       0.273441    0.631922    3.891553                    0.252827
# 4901998619       0.273441    0.631684    3.891323                    0.252827
# 4903974414       0.506302    0.628344    0.880650                    0.479049
# 4904062522       0.506359    0.628342    0.879962                    0.479106
# 4925450824       0.524450    0.668562    0.702859                    0.497151
# 4925548100       0.530037    0.701924    0.668983                    0.502737
# 4925641710       0.469511   -0.025033    0.669226                    0.442571
# 4925701385       0.469499   -0.025161    0.669235                    0.442560
# 4927303287       0.781878    4.174125    0.672129                    0.762095
# 4927405757       0.781861    4.174029    0.672330                    0.762077
# 4927726799       0.692124    2.775777    0.673504                    0.667911
# 4927831428       0.692081    2.775320    0.673661                    0.667865
# 4927909239       0.484167    0.156022    0.674016                    0.457068
# 4927978545       0.484182    0.156245    0.674058                    0.457083
# 4930013418       0.468959   -0.028798    0.672108                    0.442026
# 4930094248       0.584928    0.672165   -0.029013                    0.557996
# 4930173430       0.468936   -0.029112    0.672072                    0.442004
# 5032441973       0.325094   -1.228261    1.291056                    0.302081
#
#             radi_adv
# matchId
# 4901742097  0.327934
# 4901835876  0.327934
# 4901925673  0.327934
# 4901998619  0.327934
# 4903974414  0.327934
# 4904062522  0.327934
# 4925450824  0.327934
# 4925548100  0.327934
# 4925641710  0.327934
# 4925701385  0.327934
# 4927303287  0.327934
# 4927405757  0.327934
# 4927726799  0.327934
# 4927831428  0.327934
# 4927909239  0.327934
# 4927978545  0.327934
# 4930013418  0.327934
# 4930094248  0.327934
# 4930173430  0.327934
# 5032441973  0.327934
#
# [20 rows x 22 columns]

# %%
match_pred.df.loc[loc2].tail(20)
# Out:
#                      startDate             league_name   radiant_name  \
# matchId
# 4904171017 2019-07-14 22:09:50  The International 2019         Newbee
# 4904218149 2019-07-14 23:14:58  The International 2019        J.Storm
# 4904261164 2019-07-15 00:19:24  The International 2019         Newbee
# 4904311356 2019-07-15 01:30:53  The International 2019        J.Storm
# 4925176841 2019-07-25 16:05:44          DOTA Summit 10       Alliance
# 4925317287 2019-07-25 17:28:34          DOTA Summit 10       Alliance
# 4925450824 2019-07-25 19:00:01          DOTA Summit 10     beastcoast
# 4925548100 2019-07-25 20:20:13          DOTA Summit 10        J.Storm
# 4925748555 2019-07-26 00:17:23          DOTA Summit 10    paiN Gaming
# 4925807866 2019-07-26 01:25:54          DOTA Summit 10    paiN Gaming
# 4927545339 2019-07-26 18:22:31          DOTA Summit 10  Team Serenity
# 4927642542 2019-07-26 19:28:11          DOTA Summit 10        J.Storm
# 4927730485 2019-07-26 20:49:54          DOTA Summit 10        J.Storm
# 4927829428 2019-07-26 22:25:49          DOTA Summit 10        J.Storm
# 4929639773 2019-07-27 15:58:55          DOTA Summit 10  Team Serenity
# 4929788124 2019-07-27 17:09:59          DOTA Summit 10        J.Storm
# 4929898625 2019-07-27 18:11:11          DOTA Summit 10        J.Storm
# 5041462388 2019-09-26 13:05:46  Reshuffle Madness 2019  Positive Guys
# 5041594217 2019-09-26 14:10:54  Reshuffle Madness 2019        J.Storm
# 5041684751 2019-09-26 15:04:56  Reshuffle Madness 2019  Positive Guys
#
#                     dire_name  radiantVictory  \
# matchId
# 4904171017            J.Storm           False
# 4904218149             Newbee           False
# 4904261164            J.Storm            True
# 4904311356             Newbee           False
# 4925176841            J.Storm            True
# 4925317287            J.Storm            True
# 4925450824            J.Storm           False
# 4925548100         beastcoast           False
# 4925748555            J.Storm            True
# 4925807866            J.Storm            True
# 4927545339            J.Storm            True
# 4927642542      Team Serenity            True
# 4927730485  compLexity Gaming            True
# 4927829428  compLexity Gaming           False
# 4929639773            J.Storm           False
# 4929788124      Team Serenity           False
# 4929898625      Team Serenity           False
# 5041462388            J.Storm           False
# 5041594217      Positive Guys           False
# 5041684751            J.Storm            True
#
#                                        radiant_nicknames  \
# matchId
# 4904171017       (pieliedie, Sneyking, MSS, YawaR, CCnC)
# 4904218149           (Moo, Resolut1on, Fear, 1437, nine)
# 4904261164       (pieliedie, Sneyking, MSS, YawaR, CCnC)
# 4904311356           (Moo, Resolut1on, Fear, 1437, nine)
# 4925176841         (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4925317287         (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4925450824          (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4925548100           (Moo, Resolut1on, Fear, 1437, nine)
# 4925748555  (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4925807866  (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4927545339               (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4927642542           (Moo, Resolut1on, Fear, 1437, nine)
# 4927730485           (Moo, Resolut1on, Fear, 1437, nine)
# 4927829428           (Moo, Resolut1on, Fear, 1437, nine)
# 4929639773               (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4929788124           (Moo, Resolut1on, Fear, 1437, nine)
# 4929898625           (Moo, Resolut1on, Fear, 1437, nine)
# 5041462388      (Misha, Ghostik, iLTW, Immersion, Ergon)
# 5041594217           (Moo, Resolut1on, Fear, nine, MoOz)
# 5041684751      (Misha, Ghostik, iLTW, Immersion, Ergon)
#
#                                       dire_nicknames  seriesId  duration  \
# matchId
# 4904171017       (Moo, Resolut1on, Fear, 1437, nine)    348164      2034
# 4904218149   (pieliedie, Sneyking, MSS, YawaR, CCnC)    348164      1956
# 4904261164       (Moo, Resolut1on, Fear, 1437, nine)    348164      1901
# 4904311356   (pieliedie, Sneyking, MSS, YawaR, CCnC)    348164      1964
# 4925176841       (Moo, Resolut1on, Fear, 1437, nine)    351515      2709
# 4925317287       (Moo, Resolut1on, Fear, 1437, nine)    351515      2143
# 4925450824       (Moo, Resolut1on, Fear, 1437, nine)    351576      2952
# 4925548100      (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351576      2793
# 4925748555       (Moo, Resolut1on, Fear, 1437, nine)    351637      2355
# 4925807866       (Moo, Resolut1on, Fear, 1437, nine)    351637      2156
# 4927545339       (Moo, Resolut1on, Fear, 1437, nine)    351942      2267
# 4927642542           (Roddgee, XCJ, Zyd, Ahjit, Pyw)    351942      2580
# 4927730485       (Limmp, Zfreek, Meracle, 343, tavo)    351997      3846
# 4927829428       (Limmp, Zfreek, Meracle, 343, tavo)    351997      2318
# 4929639773       (Moo, Resolut1on, Fear, 1437, nine)    352344      2513
# 4929788124           (Roddgee, XCJ, Zyd, Ahjit, Pyw)    352344      2149
# 4929898625           (Roddgee, XCJ, Zyd, Ahjit, Pyw)    352344      2245
# 5041462388       (Moo, Resolut1on, Fear, nine, MoOz)    370933      2156
# 5041594217  (Misha, Ghostik, iLTW, Immersion, Ergon)    370933      1631
# 5041684751       (Moo, Resolut1on, Fear, nine, MoOz)    370933      2893
#
#             radiant_valveId  ...  \
# matchId                      ...
# 4904171017          6214538  ...
# 4904218149          6288801  ...
# 4904261164          6214538  ...
# 4904311356          6288801  ...
# 4925176841           111474  ...
# 4925317287           111474  ...
# 4925450824          7079109  ...
# 4925548100          6288801  ...
# 4925748555               67  ...
# 4925807866               67  ...
# 4927545339          5066616  ...
# 4927642542          6288801  ...
# 4927730485          6288801  ...
# 4927829428          6288801  ...
# 4929639773          5066616  ...
# 4929788124          6288801  ...
# 4929898625          6288801  ...
# 5041462388          7405754  ...
# 5041594217          7409177  ...
# 5041684751          7405754  ...
#
#                                                  dire_players  league_id  \
# matchId
# 4904171017  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4904218149  (6922000, 10366616, 86726887, 108452107, 22166...      10749
# 4904261164  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4904311356  (6922000, 10366616, 86726887, 108452107, 22166...      10749
# 4925176841  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925317287  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925450824  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925548100  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4925748555  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925807866  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4927545339  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4927642542  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 4927730485  (12231202, 50828662, 91369376, 111034589, 1179...      11162
# 4927829428  (12231202, 50828662, 91369376, 111034589, 1179...      11162
# 4929639773  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4929788124  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 4929898625  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 5041462388  (84429681, 86725175, 87177591, 94786276, 34931...      11210
# 5041594217  (90125566, 92847434, 113995822, 295697470, 876...      11210
# 5041684751  (84429681, 86725175, 87177591, 94786276, 34931...      11210
#
#            startTimestamp  series_start_time  match_i_in_series  \
# matchId
# 4904171017  1563142190000      1563142190000                  0
# 4904218149  1563146098000      1563142190000                  1
# 4904261164  1563149964000      1563142190000                  2
# 4904311356  1563154253000      1563142190000                  3
# 4925176841  1564070744000      1564070744000                  0
# 4925317287  1564075714000      1564070744000                  1
# 4925450824  1564081201000      1564081201000                  0
# 4925548100  1564086013000      1564081201000                  1
# 4925748555  1564100243000      1564100243000                  0
# 4925807866  1564104354000      1564100243000                  1
# 4927545339  1564165351000      1564165351000                  0
# 4927642542  1564169291000      1564165351000                  1
# 4927730485  1564174194000      1564174194000                  0
# 4927829428  1564179949000      1564174194000                  1
# 4929639773  1564243135000      1564243135000                  0
# 4929788124  1564247399000      1564243135000                  1
# 4929898625  1564251071000      1564243135000                  2
# 5041462388  1569503146000      1569503146000                  0
# 5041594217  1569507054000      1569503146000                  1
# 5041684751  1569510296000      1569503146000                  2
#
#             pred_win_prob  radi_skill  dire_skill  pred_win_prob_unknown_side  \
# matchId
# 4904171017       0.752309    3.883627    0.878665                    0.730841
# 4904218149       0.290564    0.877658    3.883537                    0.269099
# 4904261164       0.752410    3.883352    0.876758                    0.730948
# 4904311356       0.290472    0.875850    3.883057                    0.269012
# 4925176841       0.780065    4.174722    0.704514                    0.760173
# 4925317287       0.780118    4.174806    0.703678                    0.760228
# 4925450824       0.524450    0.668562    0.702859                    0.497151
# 4925548100       0.530037    0.701924    0.668983                    0.502737
# 4925748555       0.690702    2.782078    0.699804                    0.666434
# 4925807866       0.690734    2.782022    0.699299                    0.666467
# 4927545339       0.482537    0.155820    0.693398                    0.455453
# 4927642542       0.571620    0.693191    0.155739                    0.544536
# 4927730485       0.586517    0.692754   -0.028067                    0.559605
# 4927829428       0.586442    0.692038   -0.027852                    0.559529
# 4929639773       0.483504    0.161369    0.687330                    0.456411
# 4929788124       0.570593    0.686836    0.161963                    0.543499
# 4929898625       0.570545    0.686590    0.162296                    0.543451
# 5041462388       0.674795    2.532839    0.670919                    0.649956
# 5041594217       0.374860    0.670620    2.532821                    0.350022
# 5041684751       0.674817    2.532702    0.670476                    0.649979
#
#             radi_adv
# matchId
# 4904171017  0.327934
# 4904218149  0.327934
# 4904261164  0.327934
# 4904311356  0.327934
# 4925176841  0.327934
# 4925317287  0.327934
# 4925450824  0.327934
# 4925548100  0.327934
# 4925748555  0.327934
# 4925807866  0.327934
# 4927545339  0.327934
# 4927642542  0.327934
# 4927730485  0.327934
# 4927829428  0.327934
# 4929639773  0.327934
# 4929788124  0.327934
# 4929898625  0.327934
# 5041462388  0.327934
# 5041594217  0.327934
# 5041684751  0.327934
#
# [20 rows x 22 columns]

# %% [markdown]
# ### Team skills

# %%
match_pred.team_skills_plot(
    match_pred.teams.index[
        match_pred.teams.str.lower().isin([TEAM_1, TEAM_2])
    ])
# Out:
# <div>
#
#
#             <div id="a7b518dc-55d8-4038-891b-8a5e0641c0f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7b518dc-55d8-4038-891b-8a5e0641c0f8")) {
#                     Plotly.newPlot(
#                         'a7b518dc-55d8-4038-891b-8a5e0641c0f8',
#                         [{"hoverinfo": "text", "hovertext": ["<b>2018-09-29 19:13 | 4143918038</b></br></br>0 - 1 | predicted: 0.434</br></br><b>paiN  X (6214618) | 2.29</b></br>4dr (85937380) | <b>0.57</b></br>LESL\u00c3O (87063175) | <b>0.78</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.11</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.43</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.411", "<b>2018-09-29 20:15 | 4143996536</b></br></br>1 - 0 | predicted: 0.619</br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.43</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br><b>paiN  X (6214618) | 2.29</b></br>4dr (85937380) | <b>0.57</b></br>LESL\u00c3O (87063175) | <b>0.78</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.11</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.410", "<b>2018-09-29 22:11 | 4144109628</b></br></br>0 - 1 | predicted: 0.565</br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.43</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br><b>compLexity Gaming (3) | 2.95</b></br>Sneyking (10366616) | <b>1.10</b></br>Limmp (12231202) | <b>0.49</b></br>EternaLEnVy (43276219) | <b>0.56</b></br>Zfreek (50828662) | <b>0.49</b></br>Jeyo (87360406) | <b>0.31</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.409", "<b>2018-09-29 23:16 | 4144159705</b></br></br>1 - 0 | predicted: 0.489</br></br><b>compLexity Gaming (3) | 2.95</b></br>Sneyking (10366616) | <b>1.10</b></br>Limmp (12231202) | <b>0.49</b></br>EternaLEnVy (43276219) | <b>0.56</b></br>Zfreek (50828662) | <b>0.49</b></br>Jeyo (87360406) | <b>0.31</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.43</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.409", "<b>2018-09-30 19:09 | 4145830707</b></br></br>1 - 0 | predicted: 0.435</br></br><b>paiN  X (6214618) | 2.30</b></br>4dr (85937380) | <b>0.57</b></br>LESL\u00c3O (87063175) | <b>0.79</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.12</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.42</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.406", "<b>2018-09-30 21:19 | 4145961878</b></br></br>1 - 0 | predicted: 0.435</br></br><b>paiN  X (6214618) | 2.30</b></br>4dr (85937380) | <b>0.57</b></br>LESL\u00c3O (87063175) | <b>0.79</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.12</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.50</b></br>Moo (84429681) | <b>0.42</b></br>Forev (88933594) | <b>1.10</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.94</b></br></br>radi_adv: <b>0.33</b></br>J.Storm: 3.406", "<b>2018-10-07 22:48 | 4157994073</b></br></br>0 - 1 | predicted: 0.219</br></br><b>Vendetta (5636662) | -0.71</b></br> (7396553) | <b>-0.03</b></br>Noblewingz (110583422) | <b>-0.20</b></br>Gunnar (126238768) | <b>-0.14</b></br>FactorNano (134566957) | <b>-0.08</b></br>\u30df\u30d5\u30cd (140758705) | <b>-0.25</b></br></br><b>J.Storm (6288801) | 3.44</b></br>March (3940262) | <b>0.51</b></br>Moo (84429681) | <b>0.43</b></br>Forev (88933594) | <b>1.11</b></br>MiLAN (98172857) | <b>0.44</b></br>bryle (238239590) | <b>0.94</b></br></br>radi_adv: <b>0.33</b></br ...

# %% [markdown]
# ### Player skills

# %%
match_pred.player_skills_plot(team_1_players + team_2_players)
# Out:
# <div>
#
#
#             <div id="41fbff8a-9050-49bc-b912-35c3605ba7e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41fbff8a-9050-49bc-b912-35c3605ba7e3")) {
#                     Plotly.newPlot(
#                         '41fbff8a-9050-49bc-b912-35c3605ba7e3',
#                         [{"hoverinfo": "text", "hovertext": ["<b>2016-10-21 14:36 | 2724923894</b></br></br>1 - 0 | predicted: 0.566</br></br><b>Vultur (3414796) | 0.62</b></br>papita (28070572) | <b>0.15</b></br>wij (86850560) | <b>-0.01</b></br>ALGoDao (103099205) | <b>-0.05</b></br>teckla8 (120555439) | <b>-0.08</b></br>GtheSLAYER (121502553) | <b>0.60</b></br></br><b>Team DileCom (2859105) | 0.14</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>?????????? (249651648) | <b>-0.30</b></br>Shadow_ (283774700) | <b>0.22</b></br>Darky (355156901) | <b>-0.15</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.077", "<b>2016-10-21 17:15 | 2725281449</b></br></br>1 - 0 | predicted: 0.487</br></br><b>Team DileCom (2859105) | 0.14</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>?????????? (249651648) | <b>-0.30</b></br>Shadow_ (283774700) | <b>0.22</b></br>Darky (355156901) | <b>-0.15</b></br></br><b>KINGAO + 4 (1061269) | 0.63</b></br>c4t (37658157) | <b>-0.30</b></br>Kingrd (84853828) | <b>0.22</b></br>4dr (85937380) | <b>0.23</b></br>hFn (94004717) | <b>0.28</b></br>tavo (117956848) | <b>0.19</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.077", "<b>2016-10-21 18:19 | 2725401535</b></br></br>1 - 0 | predicted: 0.574</br></br><b>Team DileCom (2859105) | 0.14</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>?????????? (249651648) | <b>-0.30</b></br>Shadow_ (283774700) | <b>0.22</b></br>Darky (355156901) | <b>-0.15</b></br></br><b>Rebirth Esports (3415050) | -0.42</b></br>DarkMen l l (39155815) | <b>-0.08</b></br>ZAPBRANIGANN (86819797) | <b>-0.08</b></br>Kezia (102382586) | <b>-0.08</b></br>zap._. (215491438) | <b>-0.08</b></br>basuritashka (361266820) | <b>-0.08</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.077", "<b>2016-10-22 22:28 | 2728317804</b></br></br>1 - 0 | predicted: 0.609</br></br><b>Team DileCom (2859105) | -0.57</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>X!! (189564374) | <b>-0.49</b></br>?????????? (249651648) | <b>-0.30</b></br>Darky (355156901) | <b>-0.15</b></br></br><b>Team One ! (2788415) | -1.57</b></br>Songz (70157388) | <b>-0.33</b></br>Garb (101915970) | <b>-0.25</b></br>AnGeLMoN (102924091) | <b>-0.32</b></br>Blind (124391602) | <b>-0.33</b></br>Peace (235273853) | <b>-0.33</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.078", "<b>2016-10-22 23:47 | 2728393044</b></br></br>1 - 0 | predicted: 0.444</br></br><b>Team One ! (2788415) | -1.57</b></br>Songz (70157388) | <b>-0.33</b></br>Garb (101915970) | <b>-0.25</b></br>AnGeLMoN (102924091) | <b>-0.32</b></br>Blind (124391602) | <b>-0.33</b></br>Peace (235273853) | <b>-0.33</b></br></br><b>Team DileCom (2859105) | -0.57</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>X!! (189564374) | <b>-0.49</b></br>?????????? (249651648) | <b>-0.30</b></br>Darky (355156901) | <b>-0.15</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.078", "<b>2016-10-23 00:38 | 2728439419</b></br></br>1 - 0 | predicted: 0.444</br></br><b>Team One ! (2788415) | -1.57</b></br>Songz (70157388) | <b>-0.33</b></br>Garb (101915970) | <b>-0.25</b></br>AnGeLMoN (102924091) | <b>-0.32</b></br>Blind (124391602) | <b>-0.33</b></br>Peace (235273853) | <b>-0.33</b></br></br><b>Team DileCom (2859105) | -0.57</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>X!! (189564374) | <b>-0.49</b></br>?????????? (249651648) | <b>-0.30</b></br>Darky (355156901) | <b>-0.15</b></br></br>radi_adv: <b>0.33</b></br>Yri: -0.078", "<b>2016-10-23 14:47 | 2730074088</b></br></br>0 - 1 | predicted: 0.427</br></br><b>Team DileCom (2859105) | -0.57</b></br>Leostyle (59463394) | <b>0.46</b></br>Yri (99672424) | <b>-0.08</b></br>X!! (189564374) | <b>-0.49</b></br>?????????? (249651648) | <b>-0.30</b></br>Darky (355156901) | <b>-0.15</b></br></br><b>KINGAO + 4 (1061269) | 0.65</b></br>c4t (37658157) | <b>-0.29</b></br>Kingrd (84853828) | <b>0.22</b> ...
