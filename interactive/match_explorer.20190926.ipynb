# %% [markdown]
# # A widget for interactive analysis of a matchup

# %% [markdown]
# ## Input parameters.

# %%
TEAM_1 = 'J.Storm'
TEAM_2 = 'Team Plus'

FORCE_REFIT = True

LOGISTIC_SCALE = 3.0
COV_FUNC_NAME = 'exponential'
COV_FUNC_KWARGS = {'scale': 1.25 * 365 * 24 * 60 * 60 * 1000}
RADI_PRIOR_SD = 3.0

# %%
TEAM_1 = TEAM_1.lower()
TEAM_2 = TEAM_2.lower()

# %% [markdown]
# ## Load libraries.

# %%
import os
while 'src' not in os.listdir():
    os.chdir('..')
os.getcwd()
# Out:
# '/Users/yl3/github/dota2'

# %%
import dill
import pandas as pd

import src.load
import src.models.gp
import src.stats

# %% [markdown]
# ## Load data.

# %%
def load_premium_prof_matches():
    prem_matches = src.load.fetch_matches()
    prof_matches = src.load.fetch_matches('professional')
    matches = src.load.MatchDF(pd.concat([prem_matches.df, prof_matches.df]))
    return matches

# %%
def _match_date(matches):
    """Compute the match dates of each team by team name.

    Args:
        matches (load.MatchDF): The match data.
    """
    radi_teams = matches.df[['radiant_name', 'radiant_valveId',
                             'radiant_nicknames', 'radiant_players',
                             'startDate']]
    dire_teams = matches.df[['dire_name', 'dire_valveId',
                             'dire_nicknames', 'dire_players',
                             'startDate']]
    colnames = ['team_name', 'team_id', 'player_names', 'player_ids',
                'startDate']
    radi_teams.columns = colnames
    dire_teams.columns = colnames
    teams_by_date = (pd.concat([radi_teams, dire_teams])
                     .sort_values('startDate')
                     .reset_index())
    for colname in ('matchId', 'team_id'):
        teams_by_date[colname] = \
            teams_by_date[colname].astype(pd.Int64Dtype())
    teams_by_date['team_name'] = teams_by_date['team_name'].str.lower()
    teams_by_date.index = teams_by_date['team_name']
    return teams_by_date

# %%
serialised_model_file = 'interactive/latest_fitted_gp_model.dill'
if FORCE_REFIT or not os.path.isfile(serialised_model_file):
    matches = load_premium_prof_matches()
    gp_model = src.models.gp.SkillsGPMAP.from_match_df(
        matches,
        cov_func_name=COV_FUNC_NAME,
        cov_func_kwargs=COV_FUNC_KWARGS,
        radi_prior_sd=RADI_PRIOR_SD,
        logistic_scale=LOGISTIC_SCALE
    )
    gp_model.fit()
    display(gp_model.fitted)
    match_pred = src.stats.MatchPred(
        matches,
        gp_model.fitted_pred_df(),
        gp_model.logistic_scale,
        gp_model.fitted_skills_mat())
    with open(serialised_model_file, 'wb') as fh:
        dill.dump(match_pred, fh)
else:
    with open(serialised_model_file, 'rb') as fh:
        match_pred = dill.load(fh)
# Out:
#      fun: -248442.98370921946
#      jac: array([ 8.09542501e-07, -7.04042368e-07, -9.20713793e-07, ...,
#        -1.83662367e-07,  2.26485291e-06, -2.44725543e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 17
#     nhev: 15106
#      nit: 16
#     njev: 32
#   status: 0
#  success: True
#        x: array([ 0.11461389,  0.11431448,  0.11438803, ..., -0.03285866,
#        -0.14133105,  0.33703911])

# %% [markdown]
# ### Compute team selectors.

# %%
loc1 = ((match_pred.df.radiant_name.str.lower() == TEAM_1)
        | (match_pred.df.dire_name.str.lower() == TEAM_1))
loc2 = ((match_pred.df.radiant_name.str.lower() == TEAM_2)
        | (match_pred.df.dire_name.str.lower() == TEAM_2))
team1_id = match_pred.teams.index[match_pred.teams.str.lower() == TEAM_1][-1]
team2_id = match_pred.teams.index[match_pred.teams.str.lower() == TEAM_2][-1]

# Get the most recent roster of both teams.
match_dates = _match_date(match_pred)
team_1_players = match_dates.loc[
    match_dates.team_id == team1_id, 'player_ids'].iloc[-1]
team_2_players = match_dates.loc[
    match_dates.team_id == team2_id, 'player_ids'].iloc[-1]
    
display(match_pred.teams[match_pred.teams.str.lower() == TEAM_1])
display(match_pred.teams[match_pred.teams.str.lower() == TEAM_2])
print(f"{sum(loc1)} matches for team 1.")
print(f"{sum(loc2)} matches for team 2.")
# Out:
# 6288801    J.Storm
# 7409177    J.Storm
# dtype: object
# 7408305    Team Plus
# dtype: object
# 193 matches for team 1.
# 6 matches for team 2.

# %% [markdown]
# ## Actual interactive plots

# %% [markdown]
# ### Previous matches of both teams.

# %%
match_pred.df.loc[loc1].tail(20)
# Out:
#                      startDate                            league_name  \
# matchId
# 5043533011 2019-09-27 19:06:37  ESL One Hamburg 2019 powered by Intel
# 5043593443 2019-09-27 20:03:08  ESL One Hamburg 2019 powered by Intel
#
#                 radiant_name     dire_name  radiantVictory  \
# matchId
# 5043533011  Fighting Pepegas  Black Sheep!            True
# 5043593443  Fighting Pepegas  Black Sheep!            True
#
#                                             radiant_nicknames  \
# matchId
# 5043533011  (Sneyking, MoonMeander, Aui_2000, EternaLEnVy,...
# 5043593443  (Sneyking, MoonMeander, Aui_2000, EternaLEnVy,...
#
#                                          dire_nicknames  seriesId  duration  \
# matchId
# 5043533011  (no, Scourge McDuck, Legend, Husky, Oscar`)    371278      1792
# 5043593443  (no, Scourge McDuck, Legend, Husky, Oscar`)    371278      1677
#
#             radiant_valveId  ...  \
# matchId                      ...
# 5043533011          7391166  ...
# 5043593443          7391166  ...
#
#                                                  dire_players  league_id  \
# matchId
# 5043533011  (59752811, 85367644, 98462965, 110448679, 3526...      11275
# 5043593443  (59752811, 85367644, 98462965, 110448679, 3526...      11275
#
#            startTimestamp  series_start_time  match_i_in_series  \
# matchId
# 5043533011  1569611197000      1569611197000                  0
# 5043593443  1569614588000      1569611197000                  1
#
#             pred_win_prob  radi_skill  dire_skill  pred_win_prob_unknown_side  \
# matchId
# 5043533011       0.731559    2.028551   -0.642043                    0.708388
# 5043593443       0.731554    2.028453   -0.642065                    0.708383
#
#             radi_adv
# matchId
# 5043533011  0.337039
# 5043593443  0.337039
#
# [2 rows x 22 columns]

# %%
match_pred.df.loc[loc2].tail(20)
# Out:
#                      startDate                            league_name  \
# matchId
# 4904261164 2019-07-15 00:19:24                 The International 2019
# 4904311356 2019-07-15 01:30:53                 The International 2019
# 4925176841 2019-07-25 16:05:44                         DOTA Summit 10
# 4925317287 2019-07-25 17:28:34                         DOTA Summit 10
# 4925450824 2019-07-25 19:00:01                         DOTA Summit 10
# 4925548100 2019-07-25 20:20:13                         DOTA Summit 10
# 4925748555 2019-07-26 00:17:23                         DOTA Summit 10
# 4925807866 2019-07-26 01:25:54                         DOTA Summit 10
# 4927545339 2019-07-26 18:22:31                         DOTA Summit 10
# 4927642542 2019-07-26 19:28:11                         DOTA Summit 10
# 4927730485 2019-07-26 20:49:54                         DOTA Summit 10
# 4927829428 2019-07-26 22:25:49                         DOTA Summit 10
# 4929639773 2019-07-27 15:58:55                         DOTA Summit 10
# 4929788124 2019-07-27 17:09:59                         DOTA Summit 10
# 4929898625 2019-07-27 18:11:11                         DOTA Summit 10
# 5041462388 2019-09-26 13:05:46                 Reshuffle Madness 2019
# 5041594217 2019-09-26 14:10:54                 Reshuffle Madness 2019
# 5041684751 2019-09-26 15:04:56                 Reshuffle Madness 2019
# 5043704022 2019-09-27 22:10:46  ESL One Hamburg 2019 powered by Intel
# 5043737651 2019-09-27 23:02:32  ESL One Hamburg 2019 powered by Intel
#
#              radiant_name          dire_name  radiantVictory  \
# matchId
# 4904261164         Newbee            J.Storm            True
# 4904311356        J.Storm             Newbee           False
# 4925176841       Alliance            J.Storm            True
# 4925317287       Alliance            J.Storm            True
# 4925450824     beastcoast            J.Storm           False
# 4925548100        J.Storm         beastcoast           False
# 4925748555    paiN Gaming            J.Storm            True
# 4925807866    paiN Gaming            J.Storm            True
# 4927545339  Team Serenity            J.Storm            True
# 4927642542        J.Storm      Team Serenity            True
# 4927730485        J.Storm  compLexity Gaming            True
# 4927829428        J.Storm  compLexity Gaming           False
# 4929639773  Team Serenity            J.Storm           False
# 4929788124        J.Storm      Team Serenity           False
# 4929898625        J.Storm      Team Serenity           False
# 5041462388  Positive Guys            J.Storm           False
# 5041594217        J.Storm      Positive Guys           False
# 5041684751  Positive Guys            J.Storm            True
# 5043704022      Team Plus            J.Storm           False
# 5043737651        J.Storm          Team Plus            True
#
#                                          radiant_nicknames  \
# matchId
# 4904261164         (pieliedie, Sneyking, MSS, YawaR, CCnC)
# 4904311356             (Moo, Resolut1on, Fear, 1437, nine)
# 4925176841           (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4925317287           (iNSaNiA, Boxi, qojqva, miCKe, Taiga)
# 4925450824            (Brax, ixmike88, Ryoya, M-GOD, MoOz)
# 4925548100             (Moo, Resolut1on, Fear, 1437, nine)
# 4925748555    (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4925807866    (Stormwind, LESLÃO, hFn, Thiolicor, Unknown)
# 4927545339                 (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4927642542             (Moo, Resolut1on, Fear, 1437, nine)
# 4927730485             (Moo, Resolut1on, Fear, 1437, nine)
# 4927829428             (Moo, Resolut1on, Fear, 1437, nine)
# 4929639773                 (Roddgee, XCJ, Zyd, Ahjit, Pyw)
# 4929788124             (Moo, Resolut1on, Fear, 1437, nine)
# 4929898625             (Moo, Resolut1on, Fear, 1437, nine)
# 5041462388        (Misha, Ghostik, iLTW, Immersion, Ergon)
# 5041594217             (Moo, Resolut1on, Fear, nine, MoOz)
# 5041684751        (Misha, Ghostik, iLTW, Immersion, Ergon)
# 5043704022  (YamSun, Jenkins, GOD___Z, 김소현~, ✔ S o n i c )
# 5043737651                   (Brax, Moo, Fear, nine, MoOz)
#
#                                             dire_nicknames  seriesId  \
# matchId
# 4904261164             (Moo, Resolut1on, Fear, 1437, nine)    348164
# 4904311356         (pieliedie, Sneyking, MSS, YawaR, CCnC)    348164
# 4925176841             (Moo, Resolut1on, Fear, 1437, nine)    351515
# 4925317287             (Moo, Resolut1on, Fear, 1437, nine)    351515
# 4925450824             (Moo, Resolut1on, Fear, 1437, nine)    351576
# 4925548100            (Brax, ixmike88, Ryoya, M-GOD, MoOz)    351576
# 4925748555             (Moo, Resolut1on, Fear, 1437, nine)    351637
# 4925807866             (Moo, Resolut1on, Fear, 1437, nine)    351637
# 4927545339             (Moo, Resolut1on, Fear, 1437, nine)    351942
# 4927642542                 (Roddgee, XCJ, Zyd, Ahjit, Pyw)    351942
# 4927730485             (Limmp, Zfreek, Meracle, 343, tavo)    351997
# 4927829428             (Limmp, Zfreek, Meracle, 343, tavo)    351997
# 4929639773             (Moo, Resolut1on, Fear, 1437, nine)    352344
# 4929788124                 (Roddgee, XCJ, Zyd, Ahjit, Pyw)    352344
# 4929898625                 (Roddgee, XCJ, Zyd, Ahjit, Pyw)    352344
# 5041462388             (Moo, Resolut1on, Fear, nine, MoOz)    370933
# 5041594217        (Misha, Ghostik, iLTW, Immersion, Ergon)    370933
# 5041684751             (Moo, Resolut1on, Fear, nine, MoOz)    370933
# 5043704022                   (Brax, Moo, Fear, nine, MoOz)    371316
# 5043737651  (YamSun, Jenkins, GOD___Z, 김소현~, ✔ S o n i c )    371316
#
#             duration  radiant_valveId  ...  \
# matchId                                ...
# 4904261164      1901          6214538  ...
# 4904311356      1964          6288801  ...
# 4925176841      2709           111474  ...
# 4925317287      2143           111474  ...
# 4925450824      2952          7079109  ...
# 4925548100      2793          6288801  ...
# 4925748555      2355               67  ...
# 4925807866      2156               67  ...
# 4927545339      2267          5066616  ...
# 4927642542      2580          6288801  ...
# 4927730485      3846          6288801  ...
# 4927829428      2318          6288801  ...
# 4929639773      2513          5066616  ...
# 4929788124      2149          6288801  ...
# 4929898625      2245          6288801  ...
# 5041462388      2156          7405754  ...
# 5041594217      1631          7409177  ...
# 5041684751      2893          7405754  ...
# 5043704022      1424          7408305  ...
# 5043737651      1510          7409177  ...
#
#                                                  dire_players  league_id  \
# matchId
# 4904261164  (84429681, 86725175, 87177591, 87196890, 94786...      10749
# 4904311356  (6922000, 10366616, 86726887, 108452107, 22166...      10749
# 4925176841  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925317287  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925450824  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925548100  (31818853, 86715129, 115141430, 131706718, 349...      11162
# 4925748555  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4925807866  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4927545339  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4927642542  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 4927730485  (12231202, 50828662, 91369376, 111034589, 1179...      11162
# 4927829428  (12231202, 50828662, 91369376, 111034589, 1179...      11162
# 4929639773  (84429681, 86725175, 87177591, 87196890, 94786...      11162
# 4929788124  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 4929898625  (108717482, 117731777, 124936122, 126417273, 1...      11162
# 5041462388  (84429681, 86725175, 87177591, 94786276, 34931...      11210
# 5041594217  (90125566, 92847434, 113995822, 295697470, 876...      11210
# 5041684751  (84429681, 86725175, 87177591, 94786276, 34931...      11210
# 5043704022  (31818853, 84429681, 87177591, 94786276, 34931...      11275
# 5043737651  (81475303, 95145869, 112669497, 115165739, 287...      11275
#
#            startTimestamp  series_start_time  match_i_in_series  \
# matchId
# 4904261164  1563149964000      1563142190000                  2
# 4904311356  1563154253000      1563142190000                  3
# 4925176841  1564070744000      1564070744000                  0
# 4925317287  1564075714000      1564070744000                  1
# 4925450824  1564081201000      1564081201000                  0
# 4925548100  1564086013000      1564081201000                  1
# 4925748555  1564100243000      1564100243000                  0
# 4925807866  1564104354000      1564100243000                  1
# 4927545339  1564165351000      1564165351000                  0
# 4927642542  1564169291000      1564165351000                  1
# 4927730485  1564174194000      1564174194000                  0
# 4927829428  1564179949000      1564174194000                  1
# 4929639773  1564243135000      1564243135000                  0
# 4929788124  1564247399000      1564243135000                  1
# 4929898625  1564251071000      1564243135000                  2
# 5041462388  1569503146000      1569503146000                  0
# 5041594217  1569507054000      1569503146000                  1
# 5041684751  1569510296000      1569503146000                  2
# 5043704022  1569622246000      1569622246000                  0
# 5043737651  1569625352000      1569622246000                  1
#
#             pred_win_prob  radi_skill  dire_skill  pred_win_prob_unknown_side  \
# matchId
# 4904261164       0.750148    3.924082    0.962912                    0.727937
# 4904311356       0.294235    0.962054    3.923798                    0.272026
# 4925176841       0.775872    4.189984    0.801708                    0.755138
# 4925317287       0.775922    4.190076    0.800934                    0.755191
# 4925450824       0.528779    0.808876    0.800185                    0.500722
# 4925548100       0.527220    0.799310    0.809386                    0.499163
# 4925748555       0.685855    2.802752    0.797362                    0.660704
# 4925807866       0.685883    2.802699    0.796908                    0.660734
# 4927545339       0.477021    0.178814    0.791797                    0.449254
# 4927642542       0.578507    0.791643    0.178745                    0.550739
# 4927730485       0.594754    0.791274   -0.022644                    0.567205
# 4927829428       0.594688    0.790643   -0.022460                    0.567139
# 4929639773       0.477897    0.184460    0.786908                    0.450120
# 4929788124       0.577574    0.786482    0.185055                    0.549796
# 4929898625       0.577532    0.786296    0.185386                    0.549753
# 5041462388       0.645343    2.452526    0.993673                    0.618877
# 5041594217       0.407573    0.993470    2.452536                    0.381107
# 5041684751       0.645356    2.452432    0.993414                    0.618889
# 5043704022       0.305187   -1.597157    1.208037                    0.282455
# 5043737651       0.740272    1.208010   -1.597099                    0.717540
#
#             radi_adv
# matchId
# 4904261164  0.337039
# 4904311356  0.337039
# 4925176841  0.337039
# 4925317287  0.337039
# 4925450824  0.337039
# 4925548100  0.337039
# 4925748555  0.337039
# 4925807866  0.337039
# 4927545339  0.337039
# 4927642542  0.337039
# 4927730485  0.337039
# 4927829428  0.337039
# 4929639773  0.337039
# 4929788124  0.337039
# 4929898625  0.337039
# 5041462388  0.337039
# 5041594217  0.337039
# 5041684751  0.337039
# 5043704022  0.337039
# 5043737651  0.337039
#
# [20 rows x 22 columns]

# %% [markdown]
# ### Team skills

# %%
match_pred.team_skills_plot(
    match_pred.teams.index[
        match_pred.teams.str.lower().isin([TEAM_1, TEAM_2])
    ])
# Out:
# <div>
#
#
#             <div id="7ab42276-3d9f-4b1f-b5cb-9cbbd9f5b674" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ab42276-3d9f-4b1f-b5cb-9cbbd9f5b674")) {
#                     Plotly.newPlot(
#                         '7ab42276-3d9f-4b1f-b5cb-9cbbd9f5b674',
#                         [{"hoverinfo": "text", "hovertext": ["<b>2018-09-29 19:13 | 4143918038</b></br></br>0 - 1 | predicted: 0.434</br></br><b>paiN  X (6214618) | 2.28</b></br>4dr (85937380) | <b>0.58</b></br>LESL\u00c3O (87063175) | <b>0.77</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.10</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.46</b></br>bryle (238239590) | <b>0.98</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.409", "<b>2018-09-29 20:15 | 4143996536</b></br></br>1 - 0 | predicted: 0.620</br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.46</b></br>bryle (238239590) | <b>0.98</b></br></br><b>paiN  X (6214618) | 2.28</b></br>4dr (85937380) | <b>0.58</b></br>LESL\u00c3O (87063175) | <b>0.77</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.10</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.409", "<b>2018-09-29 22:11 | 4144109628</b></br></br>0 - 1 | predicted: 0.565</br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.46</b></br>bryle (238239590) | <b>0.98</b></br></br><b>compLexity Gaming (3) | 2.96</b></br>Sneyking (10366616) | <b>1.11</b></br>Limmp (12231202) | <b>0.49</b></br>EternaLEnVy (43276219) | <b>0.57</b></br>Zfreek (50828662) | <b>0.49</b></br>Jeyo (87360406) | <b>0.30</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.408", "<b>2018-09-29 23:16 | 4144159705</b></br></br>1 - 0 | predicted: 0.491</br></br><b>compLexity Gaming (3) | 2.96</b></br>Sneyking (10366616) | <b>1.11</b></br>Limmp (12231202) | <b>0.49</b></br>EternaLEnVy (43276219) | <b>0.57</b></br>Zfreek (50828662) | <b>0.49</b></br>Jeyo (87360406) | <b>0.30</b></br></br><b>J.Storm (6288801) | 3.41</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.46</b></br>bryle (238239590) | <b>0.98</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.407", "<b>2018-09-30 19:09 | 4145830707</b></br></br>1 - 0 | predicted: 0.435</br></br><b>paiN  X (6214618) | 2.29</b></br>4dr (85937380) | <b>0.58</b></br>LESL\u00c3O (87063175) | <b>0.78</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.10</b></br></br><b>J.Storm (6288801) | 3.40</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.98</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.405", "<b>2018-09-30 21:19 | 4145961878</b></br></br>1 - 0 | predicted: 0.435</br></br><b>paiN  X (6214618) | 2.29</b></br>4dr (85937380) | <b>0.59</b></br>LESL\u00c3O (87063175) | <b>0.78</b></br>ritsu (177648913) | <b>0.30</b></br>CCnC (221666230) | <b>0.52</b></br>FLeee (236858633) | <b>0.10</b></br></br><b>J.Storm (6288801) | 3.40</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.44</b></br>Forev (88933594) | <b>1.06</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.98</b></br></br>radi_adv: <b>0.34</b></br>J.Storm: 3.405", "<b>2018-10-07 22:48 | 4157994073</b></br></br>0 - 1 | predicted: 0.220</br></br><b>Vendetta (5636662) | -0.69</b></br> (7396553) | <b>-0.03</b></br>Noblewingz (110583422) | <b>-0.19</b></br>Gunnar (126238768) | <b>-0.13</b></br>FactorNano (134566957) | <b>-0.08</b></br>\u30df\u30d5\u30cd (140758705) | <b>-0.25</b></br></br><b>J.Storm (6288801) | 3.44</b></br>March (3940262) | <b>0.49</b></br>Moo (84429681) | <b>0.45</b></br>Forev (88933594) | <b>1.07</b></br>MiLAN (98172857) | <b>0.45</b></br>bryle (238239590) | <b>0.99</b></br></br>radi_adv: <b>0.34</b></br ...

# %% [markdown]
# ### Player skills

# %%
match_pred.player_skills_plot(team_1_players + team_2_players)
# Out:
# <div>
#
#
#             <div id="ebf97564-d20b-4ee5-9e4f-df3a2c0e26fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebf97564-d20b-4ee5-9e4f-df3a2c0e26fb")) {
#                     Plotly.newPlot(
#                         'ebf97564-d20b-4ee5-9e4f-df3a2c0e26fb',
#                         [{"hoverinfo": "text", "hovertext": ["<b>2018-09-19 17:03 | 4126592310</b></br></br>0 - 1 | predicted: 0.255</br></br><b>TEAM TEAM (6196091) | -0.09</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.07</b></br></br><b>Marchoutofarmy (5528374) | 3.46</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.45</b></br>Forev (88933594) | <b>1.07</b></br>MiLAN (98172857) | <b>0.48</b></br>bryle (238239590) | <b>0.99</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.112", "<b>2018-09-19 18:08 | 4126674003</b></br></br>1 - 0 | predicted: 0.785</br></br><b>Marchoutofarmy (5528374) | 3.46</b></br>March (3940262) | <b>0.47</b></br>Moo (84429681) | <b>0.45</b></br>Forev (88933594) | <b>1.07</b></br>MiLAN (98172857) | <b>0.48</b></br>bryle (238239590) | <b>0.99</b></br></br><b>TEAM TEAM (6196091) | -0.09</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.07</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.112", "<b>2018-09-19 22:31 | 4126904016</b></br></br>1 - 0 | predicted: 0.453</br></br><b>Black Sheep! (1366506) | -0.98</b></br>rodeo (25502245) | <b>0.19</b></br>no (59752811) | <b>-0.40</b></br>monkeys-forever (86811043) | <b>-0.13</b></br>iAnnihilate (92706637) | <b>-0.44</b></br>Boris (94364925) | <b>-0.20</b></br></br><b>TEAM TEAM (6196091) | -0.09</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.07</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.112", "<b>2018-09-19 23:57 | 4126952872</b></br></br>1 - 0 | predicted: 0.453</br></br><b>Black Sheep! (1366506) | -0.98</b></br>rodeo (25502245) | <b>0.19</b></br>no (59752811) | <b>-0.40</b></br>monkeys-forever (86811043) | <b>-0.13</b></br>iAnnihilate (92706637) | <b>-0.44</b></br>Boris (94364925) | <b>-0.20</b></br></br><b>TEAM TEAM (6196091) | -0.09</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.07</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.113", "<b>2018-09-20 17:04 | 4128152318</b></br></br>1 - 0 | predicted: 0.629</br></br><b>TEAM TEAM (6196091) | -0.08</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.06</b></br></br><b>SkrSkr (6209269) | -1.33</b></br>\uae40\uc18c\ud604~ (115165739) | <b>-0.55</b></br>Mad (124168390) | <b>0.35</b></br>JPfood (128660724) | <b>-0.59</b></br>THANKS (156745021) | <b>-0.33</b></br>zr (882896652) | <b>-0.21</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.114", "<b>2018-09-20 18:08 | 4128234098</b></br></br>1 - 0 | predicted: 0.424</br></br><b>SkrSkr (6209269) | -1.33</b></br>\uae40\uc18c\ud604~ (115165739) | <b>-0.55</b></br>Mad (124168390) | <b>0.35</b></br>JPfood (128660724) | <b>-0.59</b></br>THANKS (156745021) | <b>-0.33</b></br>zr (882896652) | <b>-0.21</b></br></br><b>TEAM TEAM (6196091) | -0.08</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | <b>-0.14</b></br>FuckinEh (86822085) | <b>-0.25</b></br>Ryoya (115141430) | <b>-0.06</b></br></br>radi_adv: <b>0.34</b></br>Brax: 0.114", "<b>2018-09-20 19:34 | 4128329364</b></br></br>0 - 1 | predicted: 0.424</br></br><b>SkrSkr (6209269) | -1.33</b></br>\uae40\uc18c\ud604~ (115165739) | <b>-0.55</b></br>Mad (124168390) | <b>0.35</b></br>JPfood (128660724) | <b>-0.59</b></br>THANKS (156745021) | <b>-0.33</b></br>zr (882896652) | <b>-0.21</b></br></br><b>TEAM TEAM (6196091) | -0.08</b></br>Newsham (1296625) | <b>0.26</b></br>Brax (31818853) | <b>0.11</b></br>ixmike88 (86715129) | ...
